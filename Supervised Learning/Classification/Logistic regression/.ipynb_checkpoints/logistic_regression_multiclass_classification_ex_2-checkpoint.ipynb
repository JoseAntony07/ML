# %%
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
dir(data)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
input_data = data.data[0]  # all 3 flowers has these features(Sepal Length, Sepal Width, Petal Length, Petal Width)
input_data  # [5.1, 3.5, 1.4, 0.2]  # Sepal Length, Sepal Width, Petal Length, Petal Width (features of flower)
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
data.target[0]  # 0 - setosa
# Out:
# np.int64(0)

# %%
data.target_names[0]  # flower 1 - setosa
# Out:
# np.str_('setosa')

# %%
data.target_names[1]  # flower 2 - versicolor
# Out:
# np.str_('versicolor')

# %%
data.target_names[2]  # flower 3 - virginica
# Out:
# np.str_('virginica')

# %%
list(data.target_names)
# Out:
# [np.str_('setosa'), np.str_('versicolor'), np.str_('virginica')]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
import pandas as pd

# Load the Iris dataset
data = load_iris()

# Create a DataFrame with the data
df = pd.DataFrame(data.data, columns=data.feature_names)
df['species'] = data.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# ...

# %%
# Use seaborn to create a pairplot of the features, colored by species
sns.pairplot(df, hue='species', diag_kind='kde', markers=['o', 's', 'D'])
plt.suptitle("Iris Dataset Visualization", y=1.02)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression


model = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %%
model.predict(X_test)
# Out:
# array([2, 0, 1, 2, 2, 1, 1, 1, 2, 0, 0, 2, 2, 0, 2, 0, 0, 1, 2, 1, 2, 0,
#        0, 2, 2, 1, 0, 1, 2, 1])

# %%
model.predict(data.data[[8]])  # setosa
# Out:
# array([0])

# %%
model.predict(data.data[[149]])  # virginica
# Out:
# array([2])

# %%
model.predict(data.data[[54]])  # versicolor
# Out:
# array([1])
